# %%
import pandas as pd
import numpy as np

# %%
fy18_html_path = "Resources/FY18_Data.xlsx"

fy18_df = pd.read_excel(fy18_html_path)
fy18_df.head()
# Out:
#      CASE_NUMBER DECISION_DATE CASE_STATUS CASE_RECEIVED_DATE REFILE  \
# 0  A-17268-91243    2017-10-01   Withdrawn         2017-09-29      N
# 1  A-17268-91198    2017-10-01   Withdrawn         2017-09-29      N
# 2  A-17275-93842    2017-10-02   Withdrawn         2017-10-02      N
# 3  A-17257-86988    2017-10-02   Withdrawn         2017-10-02      N
# 4  A-17263-89145    2017-10-02   Withdrawn         2017-10-02      N
#
#   ORIG_FILE_DATE ORIG_CASE_NO SCHD_A_SHEEPHERDER  \
# 0            NaT          NaN                  N
# 1            NaT          NaN                  N
# 2            NaT          NaN                  N
# 3            NaT          NaN                  N
# 4            NaT          NaN                  N
#
#                                        EMPLOYER_NAME  \
# 0                        DATA MEANING SERVICES GROUP
# 1                                  NOVO NORDISK INC.
# 2                     HITACHI CONSULTING CORPORATION
# ...

# %%
fy18_df['COUNTRY_OF_CITIZENSHIP'].unique()
# Out:
# array(['BRAZIL', 'INDIA', 'CHINA', 'UKRAINE', 'TAIWAN', 'SPAIN',
#        'VENEZUELA', 'ITALY', 'UNITED KINGDOM', 'SOUTH KOREA', 'MALAYSIA',
#        'COSTA RICA', 'FRANCE', 'AUSTRALIA', 'ARGENTINA', 'PAKISTAN',
#        'CANADA', 'PHILIPPINES', 'IRELAND', 'GERMANY', 'MEXICO', 'RUSSIA',
#        'NEPAL', 'BELGIUM', 'BARBADOS', 'SOUTH AFRICA', 'HONG KONG',
#        'DOMINICAN REPUBLIC', 'NETHERLANDS', 'LEBANON', 'GUATEMALA',
#        'IRAN', 'EGYPT', 'DENMARK', 'EL SALVADOR', 'JAPAN', 'ROMANIA',
#        'ISRAEL', 'SWEDEN', 'SENEGAL', 'THAILAND', 'FINLAND', 'BANGLADESH',
#        'SINGAPORE', 'SERBIA AND MONTENEGRO', 'VIETNAM', 'JAMAICA',
#        'POLAND', 'BOLIVIA', 'JORDAN', 'INDONESIA', 'CHILE', 'TURKEY',
#        'MONGOLIA', 'UZBEKISTAN', 'HONDURAS', 'PERU', 'SYRIA', 'SLOVAKIA',
#        'COLOMBIA', 'NICARAGUA', 'UNITED STATES OF AMERICA', 'URUGUAY',
#        'BULGARIA', 'TRINIDAD AND TOBAGO', 'CYPRUS', 'AUSTRIA', 'PARAGUAY',
# ...

# %%
fy18_df.columns
# Out:
# Index(['CASE_NUMBER', 'DECISION_DATE', 'CASE_STATUS', 'CASE_RECEIVED_DATE',
#        'REFILE', 'ORIG_FILE_DATE', 'ORIG_CASE_NO', 'SCHD_A_SHEEPHERDER',
#        'EMPLOYER_NAME', 'EMPLOYER_ADDRESS_1',
#        ...
#        'FW_INFO_TRAINING_COMP', 'FW_INFO_REQ_EXPERIENCE',
#        'FW_INFO_ALT_EDU_EXPERIENCE', 'FW_INFO_REL_OCCUP_EXP',
#        'PREPARER_INFO_EMP_COMPLETED', 'PREPARER_INFO_TITLE',
#        'EMPLOYER_DECL_INFO_TITLE', 'NAICS_US_CODE', 'NAICS_US_TITLE',
#        'PW_Job_Title_9089'],
#       dtype='object', length=125)

# %%
fy18_df2 = fy18_df[['CASE_NUMBER','DECISION_DATE','CASE_STATUS','CASE_RECEIVED_DATE','EMPLOYER_NAME','EMPLOYER_CITY',
                   'EMPLOYER_STATE','EMPLOYER_POSTAL_CODE','EMPLOYER_NUM_EMPLOYEES','AGENT_FIRM_NAME','AGENT_CITY',
                   'AGENT_STATE','PW_SOC_CODE','PW_SOC_TITLE','PW_AMOUNT_9089','WAGE_OFFER_FROM_9089','WAGE_OFFER_UNIT_OF_PAY_9089',
                   'JOB_INFO_WORK_CITY','JOB_INFO_WORK_STATE','JOB_INFO_WORK_POSTAL_CODE','JOB_INFO_JOB_TITLE',
                   'JOB_INFO_EDUCATION','JOB_INFO_EDUCATION_OTHER','FOREIGN_WORKER_INFO_CITY','FOREIGN_WORKER_INFO_STATE',
                   'FW_INFO_POSTAL_CODE','COUNTRY_OF_CITIZENSHIP','FW_INFO_BIRTH_COUNTRY','CLASS_OF_ADMISSION','FOREIGN_WORKER_INFO_EDUCATION','FW_INFO_EDUCATION_OTHER']]

fy18_df2.head()
# Out:
#      CASE_NUMBER DECISION_DATE CASE_STATUS CASE_RECEIVED_DATE  \
# 0  A-17268-91243    2017-10-01   Withdrawn         2017-09-29
# 1  A-17268-91198    2017-10-01   Withdrawn         2017-09-29
# 2  A-17275-93842    2017-10-02   Withdrawn         2017-10-02
# 3  A-17257-86988    2017-10-02   Withdrawn         2017-10-02
# 4  A-17263-89145    2017-10-02   Withdrawn         2017-10-02
#
#                                        EMPLOYER_NAME  EMPLOYER_CITY  \
# 0                        DATA MEANING SERVICES GROUP  CORAL SPRINGS
# 1                                  NOVO NORDISK INC.     PLAINSBORO
# 2                     HITACHI CONSULTING CORPORATION         DALLAS
# 3                     HITACHI CONSULTING CORPORATION         DALLAS
# 4  FANATICS RETAIL GROUP FULFILLMENT INC DBA FANA...   JACKSONVILLE
#
#   EMPLOYER_STATE EMPLOYER_POSTAL_CODE  EMPLOYER_NUM_EMPLOYEES  \
# 0             FL                33065                    29.0
# ...

# %%
fy18_df2.dtypes
# Out:
# CASE_NUMBER                              object
# DECISION_DATE                    datetime64[ns]
# CASE_STATUS                              object
# CASE_RECEIVED_DATE               datetime64[ns]
# EMPLOYER_NAME                            object
# EMPLOYER_CITY                            object
# EMPLOYER_STATE                           object
# EMPLOYER_POSTAL_CODE                     object
# EMPLOYER_NUM_EMPLOYEES                  float64
# AGENT_FIRM_NAME                          object
# AGENT_CITY                               object
# AGENT_STATE                              object
# PW_SOC_CODE                              object
# PW_SOC_TITLE                             object
# PW_AMOUNT_9089                           object
# WAGE_OFFER_FROM_9089                     object
# WAGE_OFFER_UNIT_OF_PAY_9089              object
# JOB_INFO_WORK_CITY                       object
# JOB_INFO_WORK_STATE                      object
# JOB_INFO_WORK_POSTAL_CODE                object
# ...

# %%
cols = ['PW_AMOUNT_9089','WAGE_OFFER_FROM_9089']

fy18_df2[cols] = fy18_df2[cols].replace({',': ''}, regex=True)

# %%
fy18_df2['PW_AMOUNT_9089'] = pd.to_numeric(fy18_df2['PW_AMOUNT_9089'])
fy18_df2['WAGE_OFFER_FROM_9089'] = pd.to_numeric(fy18_df2['WAGE_OFFER_FROM_9089'])
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
fy18_df2.dtypes
# Out:
# CASE_NUMBER                              object
# DECISION_DATE                    datetime64[ns]
# CASE_STATUS                              object
# CASE_RECEIVED_DATE               datetime64[ns]
# EMPLOYER_NAME                            object
# EMPLOYER_CITY                            object
# EMPLOYER_STATE                           object
# EMPLOYER_POSTAL_CODE                     object
# EMPLOYER_NUM_EMPLOYEES                  float64
# AGENT_FIRM_NAME                          object
# AGENT_CITY                               object
# AGENT_STATE                              object
# PW_SOC_CODE                              object
# PW_SOC_TITLE                             object
# PW_AMOUNT_9089                          float64
# WAGE_OFFER_FROM_9089                    float64
# WAGE_OFFER_UNIT_OF_PAY_9089              object
# JOB_INFO_WORK_CITY                       object
# JOB_INFO_WORK_STATE                      object
# JOB_INFO_WORK_POSTAL_CODE                object
# ...

# %%
fy18_df2.head()
# Out:
#      CASE_NUMBER DECISION_DATE CASE_STATUS CASE_RECEIVED_DATE  \
# 0  A-17268-91243    2017-10-01   Withdrawn         2017-09-29
# 1  A-17268-91198    2017-10-01   Withdrawn         2017-09-29
# 2  A-17275-93842    2017-10-02   Withdrawn         2017-10-02
# 3  A-17257-86988    2017-10-02   Withdrawn         2017-10-02
# 4  A-17263-89145    2017-10-02   Withdrawn         2017-10-02
#
#                                        EMPLOYER_NAME  EMPLOYER_CITY  \
# 0                        DATA MEANING SERVICES GROUP  CORAL SPRINGS
# 1                                  NOVO NORDISK INC.     PLAINSBORO
# 2                     HITACHI CONSULTING CORPORATION         DALLAS
# 3                     HITACHI CONSULTING CORPORATION         DALLAS
# 4  FANATICS RETAIL GROUP FULFILLMENT INC DBA FANA...   JACKSONVILLE
#
#   EMPLOYER_STATE EMPLOYER_POSTAL_CODE  EMPLOYER_NUM_EMPLOYEES  \
# 0             FL                33065                    29.0
# ...

# %%
fy18_df2['CASE_NUMBER'].count()
# Out:
# 119776

# %%
fy18_df2.to_excel("Resources/FY18_Data_Clean.xlsx")
